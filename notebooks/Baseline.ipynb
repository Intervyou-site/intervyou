# %% [markdown]
# # Baseline Model Analysis
#
# This notebook contains the baseline model implementation and analysis for the interview coaching system.

# %%
import sys
sys.path.append('..')

import pandas as pd
import numpy as np
from src.utils import load_config

# %% [markdown]
# ## Load Configuration

# %%
config = load_config('local')
print(config)

# %% [markdown]
# ## Baseline Model Implementation

# %%
# Baseline model code here
