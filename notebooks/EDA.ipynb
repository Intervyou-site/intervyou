# %% [markdown]
# # Exploratory Data Analysis (EDA)
#
# This notebook contains exploratory data analysis for the interview coaching dataset.

# %%
import sys
sys.path.append('..')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from src.utils import load_config

# %% [markdown]
# ## Data Loading and Overview

# %%
# Load and explore data
# df = pd.read_csv('../data/01-raw/dataset.csv')
# df.head()

# %% [markdown]
# ## Data Visualization

# %%
# Data visualization code here
